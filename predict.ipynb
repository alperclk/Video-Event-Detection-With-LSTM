# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.layers import Activation,Flatten,Dense,Dropout
import numpy as np
import cv2


data_dim = 63
timesteps = 224*224*3
num_classes = 2

model = Sequential()
model.add(LSTM(64, return_sequences=True,
               input_shape=(timesteps, data_dim))) 
model.add(Dropout(0.2))
model.add(LSTM(63, return_sequences=False)) 
model.add(Dropout(0.2))

model.add(Dense(63, activation='relu'))

model.add(Dense(2, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

model.load_weights("lstmModel")

# %%
def videoFrameSayisi(filepath):
    vidcap = cv2.VideoCapture(filepath) 
    frameSayisi = vidcap.get(cv2.CAP_PROP_FRAME_COUNT)
    
    vidcap.release()
    return frameSayisi

# %%
def fps(filepath):
    vidcap = cv2.VideoCapture(filepath) 
    fpsSayisi = vidcap.get(cv2.CAP_PROP_FPS)
    vidcap.release()
    return fpsSayisi

# %%
def hw(filepath):  #height, weight
    vidcap = cv2.VideoCapture(filepath) 
    success,image = vidcap.read()
    if success :
        heightwidth = image.shape[:2]  
        
    vidcap.release()
    return heightwidth

# %%
def vidoku(filepath, kontrolBaslangicFrameNo):
    imarray=np.array([])
    vidcap = cv2.VideoCapture(filepath)    
    count = 0
    
    
    while (count < kontrolBaslangicFrameNo): # kontrol edilecek yere gelene kadar sadece frameleri geç
        success,image = vidcap.read()
        if success :
            count += 1
            #print("gec" + str(count))


    while (count >= kontrolBaslangicFrameNo and count < kontrolBaslangicFrameNo + 63): # oku ve frameleri diziye kaydet
        success,image = vidcap.read()
        if success :
            count += 1
            image=cv2.resize(image,(224,224))
            imarray=np.append(imarray,image)
            #print(count)
    print( str(count) + " okundu.")
    
    vidcap.release()
    
    return imarray

# %%
def videoFrameleriOku(filepath, kontrolBaslangicFrameNo):
    frameler=[]
    vidcap = cv2.VideoCapture(filepath)    
    count = 0    
    
    while (count < kontrolBaslangicFrameNo): # kontrol edilecek yere gelene kadar sadece frameleri geç
        success,image = vidcap.read()
        if success :
            count += 1
            #print("gec" + str(count))


    while (count >= kontrolBaslangicFrameNo and count < kontrolBaslangicFrameNo + 63): # oku ve frameleri diziye kaydet
        success,image = vidcap.read()
        if success :
            count += 1            
            frameler.append(image) ###
            #print(count)
    print( str(count) + " gercek foto okundu.")
    
    vidcap.release()
    
    
    return frameler

# %%
def diziIslemleri(tahmindizisi):
    tahmindizisi=np.reshape(tahmindizisi,(-1,224*224*3))
    tahmindizisi=np.reshape(tahmindizisi,(1,224*224*3,63))
    print(tahmindizisi.shape)  
    return tahmindizisi

# %%
def anliktahmin(predict_array):
    sonuc=model.predict(predict_array)
    print(sonuc)
    return sonuc

# %%
def videoKayit(kayitAdi, frameDizisi, fps, width, height ):
    video_name = 'records/gol%d.mp4' %kayitAdi
    video = cv2.VideoWriter(video_name, cv2.VideoWriter_fourcc('M','J','P','G',), fps, (width,height))
    
    c = 0
    #frameDizisi=np.reshape(frameDizisi,(-1,224*224*3))
    for i in frameDizisi:
        video.write(i)
        cv2.imshow('son',i)
        c += 1
        
        if cv2.waitKey(25) & 0xFF == ord('q') :
            break
    print( str(c) + " frame yazıldı")
    video.release()
    cv2.destroyAllWindows()

# %%
def tahmin(filepath):
    frameSayisi = videoFrameSayisi(filepath)
    fpsSayisi = fps(filepath)
    hewi = hw(filepath)
    
    adim = 0
    golBlokSayisi = 0 
    golKayitSayisi = 0 
    kayitSayisi = 0 # kayıt metodu çağrılırken verilecek olan doğrusu
    
    tekGolFrameDizisi = [] # kontrol edilen 63 framelik bloklar peşpeşe gol ise o da tutulacak
    golFrameler = []
    vidFrOku = []
    bosDizi = []
    oncekiKontrol = 0
    
    while ( ( adim * 63 ) + 63 < frameSayisi ):
        print( str( adim * 63 ) + "/" + str( adim * 63 + 63 ) + " arası frameler kontrol için okunuyor..." )
        images=vidoku(path, (adim * 63 ) )   
        sonuc = anliktahmin(diziIslemleri(images))    
        
        gol=sonuc[0][0]
        faul=sonuc[0][1]
        if(gol>faul):  # gol ise
            print("GOL BLOĞU TESPİT EDİLDİ")
            golBlokSayisi += 1            
            
            if ( ( (adim + 1) * 63 ) + 63 > frameSayisi ): # bir sonra bakacağı blok videonun dışına çıkacaksa (video bitecekse)
                golKayitSayisi += 1
                vidFrOku = videoFrameleriOku(path, (adim * 63 ) )
                print ( len(vidFrOku) ) 
                print("frame var")
                for i in ( (vidFrOku) ):
                    golFrameler.append( i )
                
                #tekGolFrameDizisi = tekGolFrameDizisi.append(images)
                videoKayit ( golKayitSayisi, golFrameler, fpsSayisi, hewi[1], hewi[0]  )  # golü kaydet
                #tekGolFrameDizisi = bosDizi
                #golFrameler = bosDizi
                golFrameler.clear()
                vidFrOku.clear()
            else :    
                
                vidFrOku = videoFrameleriOku(path, (adim * 63 ) )
                print ( len(vidFrOku) ) 
                print("frame var")
                for i in ( (vidFrOku) ):
                    golFrameler.append( i )
                vidFrOku.clear()
                #for i in ( videoFrameleriOku(path, (adim * 63 ) ) ):
                    #golFrameler.append( i )
                    
                #golFrameler.append( videoFrameleriOku(path, (adim * 63 ) ) )
                #tekGolFrameDizisi = tekGolFrameDizisi.append(images)   # gol tespit edileni aklında tutar         
                
            oncekiKontrol = 1    
            adim += 1           
              
            
        else :   # gol değilse
            if ( oncekiKontrol == 1 ): # anlik tespit gol değil ise ancak bir öncesinde gol tespit edilip hafızaya alındıysa
                golKayitSayisi += 1
                videoKayit ( golKayitSayisi, golFrameler, fpsSayisi, hewi[1], hewi[0]  )  # golü kaydet
                #tekGolFrameDizisi = bosDizi
                golFrameler.clear()
            oncekiKontrol = 0
            adim += 1

# %%
#path="vid/ronaldene.mp4"
path="test/bilinmeyen.mp4"

tahmin(path)


cv2.destroyAllWindows()
# Out:
# 0/63 arası frameler kontrol için okunuyor...
# 63 okundu.
# (1, 150528, 63)
# [[0.2450937 0.7549063]]
# 63/126 arası frameler kontrol için okunuyor...
# 126 okundu.
# (1, 150528, 63)
# [[0.13402332 0.8659767 ]]
# 126/189 arası frameler kontrol için okunuyor...
# 189 okundu.
# (1, 150528, 63)
# [[0.08437454 0.91562545]]
# 189/252 arası frameler kontrol için okunuyor...
# 252 okundu.
# (1, 150528, 63)
# [[0.5912767  0.40872324]]
# GOL BLOĞU TESPİT EDİLDİ
# 252 gercek foto okundu.
# 63
# frame var
# 252/315 arası frameler kontrol için okunuyor...
# 315 okundu.
# (1, 150528, 63)
# [[0.66233605 0.33766392]]
# GOL BLOĞU TESPİT EDİLDİ
# 315 gercek foto okundu.
# 63
# frame var
# 315/378 arası frameler kontrol için okunuyor...
# 378 okundu.
# (1, 150528, 63)
# [[0.7113993  0.28860068]]
# GOL BLOĞU TESPİT EDİLDİ
# 378 gercek foto okundu.
# 63
# frame var
# 378/441 arası frameler kontrol için okunuyor...
# 441 okundu.
# (1, 150528, 63)
# [[0.44607747 0.55392253]]
# 189 frame yazıldı
# 441/504 arası frameler kontrol için okunuyor...
# 504 okundu.
# (1, 150528, 63)
# [[0.6214051 0.3785949]]
# GOL BLOĞU TESPİT EDİLDİ
# 504 gercek foto okundu.
# 63
# frame var
# 504/567 arası frameler kontrol için okunuyor...
# 567 okundu.
# (1, 150528, 63)
# [[0.6498561  0.35014394]]
# GOL BLOĞU TESPİT EDİLDİ
# 567 gercek foto okundu.
# 63
# frame var
# 567/630 arası frameler kontrol için okunuyor...
# 630 okundu.
# (1, 150528, 63)
# [[0.6877134  0.31228665]]
# GOL BLOĞU TESPİT EDİLDİ
# 630 gercek foto okundu.
# 63
# frame var
# 630/693 arası frameler kontrol için okunuyor...
# 693 okundu.
# (1, 150528, 63)
# [[0.4562077  0.54379225]]
# 189 frame yazıldı
# 693/756 arası frameler kontrol için okunuyor...
# 756 okundu.
# (1, 150528, 63)
# [[0.3654339 0.6345661]]
# 756/819 arası frameler kontrol için okunuyor...
# 819 okundu.
# (1, 150528, 63)
# [[0.08290841 0.91709167]]
# 819/882 arası frameler kontrol için okunuyor...
# 882 okundu.
# (1, 150528, 63)
# [[0.08803857 0.91196144]]
# 882/945 arası frameler kontrol için okunuyor...
# 945 okundu.
# (1, 150528, 63)
# [[0.08201618 0.91798383]]
# 945/1008 arası frameler kontrol için okunuyor...
# 1008 okundu.
# (1, 150528, 63)
# [[0.08386187 0.9161382 ]]
# 1008/1071 arası frameler kontrol için okunuyor...
# 1071 okundu.
# (1, 150528, 63)
# [[0.76644844 0.23355152]]
# GOL BLOĞU TESPİT EDİLDİ
# 1071 gercek foto okundu.
# 63
# frame var
# 1071/1134 arası frameler kontrol için okunuyor...
# 1134 okundu.
# (1, 150528, 63)
# [[0.8135998  0.18640019]]
# GOL BLOĞU TESPİT EDİLDİ
# 1134 gercek foto okundu.
# 63
# frame var
# 1134/1197 arası frameler kontrol için okunuyor...
# 1197 okundu.
# (1, 150528, 63)
# [[0.69506025 0.30493972]]
# GOL BLOĞU TESPİT EDİLDİ
# 1197 gercek foto okundu.
# 63
# frame var
# 1197/1260 arası frameler kontrol için okunuyor...
# 1260 okundu.
# (1, 150528, 63)
# [[0.5783805  0.42161942]]
# GOL BLOĞU TESPİT EDİLDİ
# 1260 gercek foto okundu.
# 63
# frame var
# 1260/1323 arası frameler kontrol için okunuyor...
# 1323 okundu.
# (1, 150528, 63)
# [[0.58174884 0.4182511 ]]
# GOL BLOĞU TESPİT EDİLDİ
# 1323 gercek foto okundu.
# 63
# frame var
# 1323/1386 arası frameler kontrol için okunuyor...
# 1386 okundu.
# (1, 150528, 63)
# [[0.71226543 0.2877346 ]]
# GOL BLOĞU TESPİT EDİLDİ
# 1386 gercek foto okundu.
# 63
# frame var
# 1386/1449 arası frameler kontrol için okunuyor...
# 1449 okundu.
# (1, 150528, 63)
# [[0.815052   0.18494801]]
# GOL BLOĞU TESPİT EDİLDİ
# 1449 gercek foto okundu.
# 63
# frame var
# 1449/1512 arası frameler kontrol için okunuyor...
# 1512 okundu.
# (1, 150528, 63)
# [[0.9959073  0.00409264]]
# GOL BLOĞU TESPİT EDİLDİ
# 1512 gercek foto okundu.
# 63
# frame var
# 1512/1575 arası frameler kontrol için okunuyor...
# 1575 okundu.
# (1, 150528, 63)
# [[0.5957297  0.40427035]]
# GOL BLOĞU TESPİT EDİLDİ
# 1575 gercek foto okundu.
# 63
# frame var
# 1575/1638 arası frameler kontrol için okunuyor...
# 1638 okundu.
# (1, 150528, 63)
# [[0.45937112 0.54062885]]
# 567 frame yazıldı
# 1638/1701 arası frameler kontrol için okunuyor...
# 1701 okundu.
# (1, 150528, 63)
# [[0.793168 0.206832]]
# GOL BLOĞU TESPİT EDİLDİ
# 1701 gercek foto okundu.
# 63
# frame var
# 1701/1764 arası frameler kontrol için okunuyor...
# 1764 okundu.
# (1, 150528, 63)
# [[0.69652414 0.30347583]]
# GOL BLOĞU TESPİT EDİLDİ
# 1764 gercek foto okundu.
# 63
# frame var
# 1764/1827 arası frameler kontrol için okunuyor...
# 1827 okundu.
# (1, 150528, 63)
# [[0.6976582  0.30234182]]
# GOL BLOĞU TESPİT EDİLDİ
# 1827 gercek foto okundu.
# 63
# frame var
# 1827/1890 arası frameler kontrol için okunuyor...
# 1890 okundu.
# (1, 150528, 63)
# [[0.49888927 0.5011107 ]]
# 189 frame yazıldı
# 1890/1953 arası frameler kontrol için okunuyor...
# 1953 okundu.
# (1, 150528, 63)
# [[0.46240976 0.53759027]]
# 1953/2016 arası frameler kontrol için okunuyor...
# 2016 okundu.
# (1, 150528, 63)
# [[0.6119821  0.38801792]]
# GOL BLOĞU TESPİT EDİLDİ
# 2016 gercek foto okundu.
# 63
# frame var
# 2016/2079 arası frameler kontrol için okunuyor...
# 2079 okundu.
# (1, 150528, 63)
# [[0.6150293  0.38497078]]
# GOL BLOĞU TESPİT EDİLDİ
# 2079 gercek foto okundu.
# 63
# frame var
# 2079/2142 arası frameler kontrol için okunuyor...
# 2142 okundu.
# (1, 150528, 63)
# [[0.5611961  0.43880394]]
# GOL BLOĞU TESPİT EDİLDİ
# 2142 gercek foto okundu.
# 63
# frame var
# 2142/2205 arası frameler kontrol için okunuyor...
# 2205 okundu.
# (1, 150528, 63)
# [[0.5638755 0.4361245]]
# GOL BLOĞU TESPİT EDİLDİ
# 2205 gercek foto okundu.
# 63
# frame var
# 2205/2268 arası frameler kontrol için okunuyor...
# 2268 okundu.
# (1, 150528, 63)
# [[0.60593504 0.39406496]]
# GOL BLOĞU TESPİT EDİLDİ
# 2268 gercek foto okundu.
# 63
# frame var
# 2268/2331 arası frameler kontrol için okunuyor...
# 2331 okundu.
# (1, 150528, 63)
# [[0.7605575  0.23944251]]
# GOL BLOĞU TESPİT EDİLDİ
# 2331 gercek foto okundu.
# 63
# frame var
# 2331/2394 arası frameler kontrol için okunuyor...
# 2394 okundu.
# (1, 150528, 63)
# [[0.78980374 0.21019629]]
# GOL BLOĞU TESPİT EDİLDİ
# 2394 gercek foto okundu.
# 63
# frame var
# 2394/2457 arası frameler kontrol için okunuyor...
# 2457 okundu.
# (1, 150528, 63)
# [[0.77796507 0.22203496]]
# GOL BLOĞU TESPİT EDİLDİ
# 2457 gercek foto okundu.
# 63
# frame var
# 2457/2520 arası frameler kontrol için okunuyor...
# 2520 okundu.
# (1, 150528, 63)
# [[0.75208175 0.24791825]]
# GOL BLOĞU TESPİT EDİLDİ
# 2520 gercek foto okundu.
# 63
# frame var
# 2520/2583 arası frameler kontrol için okunuyor...
# 2583 okundu.
# (1, 150528, 63)
# [[0.5704648  0.42953518]]
# GOL BLOĞU TESPİT EDİLDİ
# 2583 gercek foto okundu.
# 63
# frame var
# 2583/2646 arası frameler kontrol için okunuyor...
# 2646 okundu.
# (1, 150528, 63)
# [[0.70252776 0.29747224]]
# GOL BLOĞU TESPİT EDİLDİ
# 2646 gercek foto okundu.
# 63
# frame var
# 2646/2709 arası frameler kontrol için okunuyor...
# 2709 okundu.
# (1, 150528, 63)
# [[0.44297627 0.5570237 ]]
# 693 frame yazıldı
# 2709/2772 arası frameler kontrol için okunuyor...
# 2772 okundu.
# (1, 150528, 63)
# [[0.6841752 0.3158248]]
# GOL BLOĞU TESPİT EDİLDİ
# 2772 gercek foto okundu.
# 63
# frame var
# 2772/2835 arası frameler kontrol için okunuyor...
# 2835 okundu.
# (1, 150528, 63)
# [[0.72812235 0.27187768]]
# GOL BLOĞU TESPİT EDİLDİ
# 2835 gercek foto okundu.
# 63
# frame var
# 2835/2898 arası frameler kontrol için okunuyor...
# 2898 okundu.
# (1, 150528, 63)
# [[0.68966794 0.31033203]]
# GOL BLOĞU TESPİT EDİLDİ
# 2898 gercek foto okundu.
# 63
# frame var
# 2898/2961 arası frameler kontrol için okunuyor...
# 2961 okundu.
# (1, 150528, 63)
# [[0.91554135 0.08445868]]
# GOL BLOĞU TESPİT EDİLDİ
# 2961 gercek foto okundu.
# 63
# frame var
# 2961/3024 arası frameler kontrol için okunuyor...
# 3024 okundu.
# (1, 150528, 63)
# [[0.7314827  0.26851735]]
# GOL BLOĞU TESPİT EDİLDİ
# 3024 gercek foto okundu.
# 63
# frame var
# 3024/3087 arası frameler kontrol için okunuyor...
# 3087 okundu.
# (1, 150528, 63)
# [[0.64955217 0.3504478 ]]
# GOL BLOĞU TESPİT EDİLDİ
# 3087 gercek foto okundu.
# 63
# frame var
# 3087/3150 arası frameler kontrol için okunuyor...
# 3150 okundu.
# (1, 150528, 63)
# [[0.6325919  0.36740807]]
# GOL BLOĞU TESPİT EDİLDİ
# 3150 gercek foto okundu.
# 63
# frame var
# 3150/3213 arası frameler kontrol için okunuyor...
# 3213 okundu.
# (1, 150528, 63)
# [[0.9961532  0.00384686]]
# GOL BLOĞU TESPİT EDİLDİ
# 3213 gercek foto okundu.
# 63
# frame var
# 3213/3276 arası frameler kontrol için okunuyor...
# 3276 okundu.
# (1, 150528, 63)
# [[0.5097531 0.4902469]]
# GOL BLOĞU TESPİT EDİLDİ
# 3276 gercek foto okundu.
# 63
# frame var
# 3276/3339 arası frameler kontrol için okunuyor...
# 3339 okundu.
# (1, 150528, 63)
# [[0.99620396 0.00379606]]
# GOL BLOĞU TESPİT EDİLDİ
# 3339 gercek foto okundu.
# 63
# frame var
# 3339/3402 arası frameler kontrol için okunuyor...
# 3402 okundu.
# (1, 150528, 63)
# [[0.81172615 0.18827386]]
# GOL BLOĞU TESPİT EDİLDİ
# 3402 gercek foto okundu.
# 63
# frame var
# 3402/3465 arası frameler kontrol için okunuyor...
# 3465 okundu.
# (1, 150528, 63)
# [[0.5982986 0.4017014]]
# GOL BLOĞU TESPİT EDİLDİ
# 3465 gercek foto okundu.
# 63
# frame var
# 3465/3528 arası frameler kontrol için okunuyor...
# 3528 okundu.
# (1, 150528, 63)
# [[0.43183923 0.56816083]]
# 756 frame yazıldı
# 3528/3591 arası frameler kontrol için okunuyor...
# 3591 okundu.
# (1, 150528, 63)
# [[0.534282   0.46571797]]
# GOL BLOĞU TESPİT EDİLDİ
# 3591 gercek foto okundu.
# 63
# frame var
# 3591/3654 arası frameler kontrol için okunuyor...
# 3654 okundu.
# (1, 150528, 63)
# [[0.7450646  0.25493535]]
# GOL BLOĞU TESPİT EDİLDİ
# 3654 gercek foto okundu.
# 63
# frame var
# 3654/3717 arası frameler kontrol için okunuyor...
# 3717 okundu.
# (1, 150528, 63)
# [[0.98968995 0.01031005]]
# GOL BLOĞU TESPİT EDİLDİ
# 3717 gercek foto okundu.
# 63
# frame var
# 3717/3780 arası frameler kontrol için okunuyor...
# 3780 okundu.
# (1, 150528, 63)
# [[0.9828699  0.01713011]]
# GOL BLOĞU TESPİT EDİLDİ
# 3780 gercek foto okundu.
# 63
# frame var
# 3780/3843 arası frameler kontrol için okunuyor...
# 3843 okundu.
# (1, 150528, 63)
# [[0.9949517  0.00504824]]
# GOL BLOĞU TESPİT EDİLDİ
# 3843 gercek foto okundu.
# 63
# frame var
# 3843/3906 arası frameler kontrol için okunuyor...
# 3906 okundu.
# (1, 150528, 63)
# [[0.79986244 0.20013751]]
# GOL BLOĞU TESPİT EDİLDİ
# 3906 gercek foto okundu.
# 63
# frame var
# 3906/3969 arası frameler kontrol için okunuyor...
# 3969 okundu.
# (1, 150528, 63)
# [[0.74622774 0.2537723 ]]
# GOL BLOĞU TESPİT EDİLDİ
# 3969 gercek foto okundu.
# 63
# frame var
# 3969/4032 arası frameler kontrol için okunuyor...
# 4032 okundu.
# (1, 150528, 63)
# [[0.82008344 0.17991656]]
# GOL BLOĞU TESPİT EDİLDİ
# 4032 gercek foto okundu.
# 63
# frame var
# 4032/4095 arası frameler kontrol için okunuyor...
# 4095 okundu.
# (1, 150528, 63)
# [[0.89952224 0.1004778 ]]
# GOL BLOĞU TESPİT EDİLDİ
# 4095 gercek foto okundu.
# 63
# frame var
# 4095/4158 arası frameler kontrol için okunuyor...
# 4158 okundu.
# (1, 150528, 63)
# [[0.6706597  0.32934028]]
# GOL BLOĞU TESPİT EDİLDİ
# 4158 gercek foto okundu.
# 63
# frame var
# 4158/4221 arası frameler kontrol için okunuyor...
# 4221 okundu.
# (1, 150528, 63)
# [[0.85658455 0.14341545]]
# GOL BLOĞU TESPİT EDİLDİ
# 4221 gercek foto okundu.
# 63
# frame var
# 4221/4284 arası frameler kontrol için okunuyor...
# 4284 okundu.
# (1, 150528, 63)
# [[0.36815742 0.63184255]]
# 693 frame yazıldı
# 4284/4347 arası frameler kontrol için okunuyor...
# 4347 okundu.
# (1, 150528, 63)
# [[0.51953906 0.48046094]]
# GOL BLOĞU TESPİT EDİLDİ
# 4347 gercek foto okundu.
# 63
# frame var
# 4347/4410 arası frameler kontrol için okunuyor...
# 4410 okundu.
# (1, 150528, 63)
# [[0.7002164 0.2997836]]
# GOL BLOĞU TESPİT EDİLDİ
# 4410 gercek foto okundu.
# 63
# frame var
# 4410/4473 arası frameler kontrol için okunuyor...
# 4473 okundu.
# (1, 150528, 63)
# [[0.71253574 0.28746423]]
# GOL BLOĞU TESPİT EDİLDİ
# 4473 gercek foto okundu.
# 63
# frame var
# 4473/4536 arası frameler kontrol için okunuyor...
# 4536 okundu.
# (1, 150528, 63)
# [[0.74008566 0.25991434]]
# GOL BLOĞU TESPİT EDİLDİ
# 4536 gercek foto okundu.
# 63
# frame var
# 4536/4599 arası frameler kontrol için okunuyor...
# 4599 okundu.
# (1, 150528, 63)
# [[0.40106106 0.59893894]]
# 252 frame yazıldı
# 4599/4662 arası frameler kontrol için okunuyor...
# 4662 okundu.
# (1, 150528, 63)
# [[0.40546125 0.59453875]]
# 4662/4725 arası frameler kontrol için okunuyor...
# 4725 okundu.
# (1, 150528, 63)
# [[0.2915033 0.7084967]]
# 4725/4788 arası frameler kontrol için okunuyor...
# 4788 okundu.
# (1, 150528, 63)
# [[0.60921514 0.39078486]]
# GOL BLOĞU TESPİT EDİLDİ
# 4788 gercek foto okundu.
# 63
# frame var
# 4788/4851 arası frameler kontrol için okunuyor...
# 4851 okundu.
# (1, 150528, 63)
# [[0.6359108 0.3640892]]
# GOL BLOĞU TESPİT EDİLDİ
# 4851 gercek foto okundu.
# 63
# frame var
# 4851/4914 arası frameler kontrol için okunuyor...
# 4914 okundu.
# (1, 150528, 63)
# [[0.5569153  0.44308475]]
# GOL BLOĞU TESPİT EDİLDİ
# 4914 gercek foto okundu.
# 63
# frame var
# 4914/4977 arası frameler kontrol için okunuyor...
# 4977 okundu.
# (1, 150528, 63)
# [[0.58776224 0.41223776]]
# GOL BLOĞU TESPİT EDİLDİ
# 4977 gercek foto okundu.
# 63
# frame var
# 4977/5040 arası frameler kontrol için okunuyor...
# 5040 okundu.
# (1, 150528, 63)
# [[0.515707   0.48429304]]
# GOL BLOĞU TESPİT EDİLDİ
# 5040 gercek foto okundu.
# 63
# frame var
# 5040/5103 arası frameler kontrol için okunuyor...
# 5103 okundu.
# (1, 150528, 63)
# [[0.53829056 0.4617095 ]]
# GOL BLOĞU TESPİT EDİLDİ
# 5103 gercek foto okundu.
# 63
# frame var
# 5103/5166 arası frameler kontrol için okunuyor...
# 5166 okundu.
# (1, 150528, 63)
# [[0.5347158 0.4652843]]
# GOL BLOĞU TESPİT EDİLDİ
# 5166 gercek foto okundu.
# 63
# frame var
# 5166/5229 arası frameler kontrol için okunuyor...
# 5229 okundu.
# (1, 150528, 63)
# [[0.455303 0.544697]]
# 441 frame yazıldı
# 5229/5292 arası frameler kontrol için okunuyor...
# 5292 okundu.
# (1, 150528, 63)
# [[0.60941744 0.3905825 ]]
# GOL BLOĞU TESPİT EDİLDİ
# 5292 gercek foto okundu.
# 63
# frame var
# 5292/5355 arası frameler kontrol için okunuyor...
# 5355 okundu.
# (1, 150528, 63)
# [[0.5850525  0.41494757]]
# GOL BLOĞU TESPİT EDİLDİ
# 5355 gercek foto okundu.
# 63
# frame var
# 5355/5418 arası frameler kontrol için okunuyor...
# 5418 okundu.
# (1, 150528, 63)
# [[0.5462223 0.4537777]]
# GOL BLOĞU TESPİT EDİLDİ
# 5418 gercek foto okundu.
# 63
# frame var
# 5418/5481 arası frameler kontrol için okunuyor...
# 5481 okundu.
# (1, 150528, 63)
# [[0.6486143 0.3513857]]
# GOL BLOĞU TESPİT EDİLDİ
# 5481 gercek foto okundu.
# 63
# frame var
# 5481/5544 arası frameler kontrol için okunuyor...
# 5544 okundu.
# (1, 150528, 63)
